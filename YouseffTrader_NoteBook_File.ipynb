# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Youseff Trade Analysis Week 2 2025.xlsx')
data.head(10)
# Out:
#         Date Currency Pairs  Martingale      Time Option Win/Loss    Session
# 0 2025-01-06    EUR/USD OTC           0  00:35:00   Sell      Win  Overnight
# 1 2025-01-06    GBP/AUD OTC           3  00:50:00   Sell     Loss  Overnight
# 2 2025-01-06    USD/JPY OTC           2  01:20:00   Sell      Win  Overnight
# 3 2025-01-06    EUR/USD OTC           0  01:45:00   Sell      Win  Overnight
# 4 2025-01-06    USD/CHF OTC           0  02:00:00    Buy      Win  Overnight
# 5 2025-01-06    GBP/USD OTC           2  02:15:00    Buy      Win  Overnight
# 6 2025-01-06    USD/CNH OTC           0  02:40:00   Sell      Win  Overnight
# 7 2025-01-06    GBP/JPY OTC           0  02:55:00    Buy      Win  Overnight
# 8 2025-01-06    USD/CAD OTC           3  03:10:00   Sell      Win  Overnight
# 9 2025-01-06    GBP/USD OTC           2  03:40:00    Buy      Win  Overnight

# %%
# Step one: Replace all instances of 0 in "Martigale" with "Entry"
data['Martingale'] = data['Martingale'].replace(0, "Entry")

# %%
data.head()
# Out:
#         Date Currency Pairs Martingale      Time Option Win/Loss    Session
# 0 2025-01-06    EUR/USD OTC      Entry  00:35:00   Sell      Win  Overnight
# 1 2025-01-06    GBP/AUD OTC          3  00:50:00   Sell     Loss  Overnight
# 2 2025-01-06    USD/JPY OTC          2  01:20:00   Sell      Win  Overnight
# 3 2025-01-06    EUR/USD OTC      Entry  01:45:00   Sell      Win  Overnight
# 4 2025-01-06    USD/CHF OTC      Entry  02:00:00    Buy      Win  Overnight

# %%
# Step one: Replace all instances of 1 in "Martigale" with "First"
data['Martingale'] = data['Martingale'].replace(1, "First")
data['Martingale'] = data['Martingale'].replace(2, "Second")
data['Martingale'] = data['Martingale'].replace(3, "Third")

# %%
data.head(20)
# Out:
#          Date Currency Pairs Martingale      Time Option Win/Loss    Session
# 0  2025-01-06    EUR/USD OTC      Entry  00:35:00   Sell      Win  Overnight
# 1  2025-01-06    GBP/AUD OTC      Third  00:50:00   Sell     Loss  Overnight
# 2  2025-01-06    USD/JPY OTC     Second  01:20:00   Sell      Win  Overnight
# 3  2025-01-06    EUR/USD OTC      Entry  01:45:00   Sell      Win  Overnight
# 4  2025-01-06    USD/CHF OTC      Entry  02:00:00    Buy      Win  Overnight
# 5  2025-01-06    GBP/USD OTC     Second  02:15:00    Buy      Win  Overnight
# 6  2025-01-06    USD/CNH OTC      Entry  02:40:00   Sell      Win  Overnight
# 7  2025-01-06    GBP/JPY OTC      Entry  02:55:00    Buy      Win  Overnight
# 8  2025-01-06    USD/CAD OTC      Third  03:10:00   Sell      Win  Overnight
# 9  2025-01-06    GBP/USD OTC     Second  03:40:00    Buy      Win  Overnight
# 10 2025-01-06    USD/CAD OTC      Third  04:25:00   Sell      Win  Overnight
# ...

# %%
data.to_excel("Corrected_Youseff_Trade_Analysis.xlsx", index=False)
